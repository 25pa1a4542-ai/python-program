# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a4542-ai/python-program/blob/main/Program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("pravallika")
# Out:
# pravallika

# %%
x=int(input("enter a number"))
y=int(input("enter a another number"))
#arithmetic operators
print(x+y,"is the sum of x and y")
print(x-y,"is the subraction of x and y")
print(x*y,"is the multiplication of x and y")
print(x/y,"is the division of x and y")
print(x%y,"is the remainder in division ")
print(x**y,"is the power of x and y")
print(x//y,"is the is th dividion with type casting")
# Out:
# enter a number7
# enter a another number2
# 9 is the sum of x and y
# 5 is the subraction of x and y
# 14 is the multiplication of x and y
# 3.5 is the division of x and y
# 1 is the remainder in division
# 49 is the power of x and y
# 3 is the is th dividion with type casting

# %%
#comparision operators
print(x==y)
print(x!=y)
print(x<=y)
print(x>=y)
print(x<y)
print(x>y)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#Assignment operators
